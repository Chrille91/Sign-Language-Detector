# %% [markdown]
# # Sign Language Detection Project

# %%
import numpy as np

# %%
# Path for exported data, numpy arrays

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
# %pip install google-colab
# !pwd
# Out:
# Der Befehl "pwd" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %%
# not being used now - mounting google drive to be able to access files in the folder
# %pip install google-colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Collecting google-colab
#   Downloading google-colab-1.0.0.tar.gz (72 kB)
#      ---------------------------------------- 0.0/72.9 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/72.9 kB ? eta -:--:--
#      --------------------- ---------------- 41.0/72.9 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 72.9/72.9 kB 803.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting google-auth~=1.4.0 (from google-colab)
#   Obtaining dependency information for google-auth~=1.4.0 from https://files.pythonhosted.org/packages/56/80/369a47c28ce7d9be6a6973338133d073864d8efbb62747e414c34a3a5f4f/google_auth-1.4.2-py2.py3-none-any.whl.metadata
#   Downloading google_auth-1.4.2-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting ipykernel~=4.6.0 (from google-colab)
#   Obtaining dependency information for ipykernel~=4.6.0 from https://files.pythonhosted.org/packages/18/c3/76775a650cae2e3d9c033b26153583e61282692d9a3af12a3022d8f0cefa/ipykernel-4.6.1-py3-none-any.whl.metadata
#   Downloading ipykernel-4.6.1-py3-none-any.whl.metadata (981 bytes)
# Collecting ipython~=5.5.0 (from google-colab)
#   Obtaining dependency information for ipython~=5.5.0 from https://files.pythonhosted.org/packages/07/63/c987612bcf82c56eaacaf6bf01e31e53a244a0a3a0fb036ec5adc377e0fe/ipython-5.5.0-py3-none-any.whl.metadata
#   Downloading ipython-5.5.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting notebook~=5.2.0 (from google-colab)
#   Obtaining dependency information for notebook~=5.2.0 from https://files.pythonhosted.org/packages/96/a2/d951ebb7855743f989287486ded73cd3f66915c3ecd9c5c5a0c7ca12377a/notebook-5.2.2-py2.py3-none-any.whl.metadata
#   Downloading notebook-5.2.2-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting six~=1.12.0 (from google-colab)
#   Obtaining dependency information for six~=1.12.0 from https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl.metadata
#   Downloading six-1.12.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting pandas~=0.24.0 (from google-colab)
#   Downloading pandas-0.24.2.tar.gz (11.8 MB)
#      ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#       --------------------------------------- 0.2/11.8 MB 4.6 MB/s eta 0:00:03
#      - -------------------------------------- 0.4/11.8 MB 4.5 MB/s eta 0:00:03
#      - -------------------------------------- 0.5/11.8 MB 4.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.7/11.8 MB 3.8 MB/s eta 0:00:03
#      -- ------------------------------------- 0.8/11.8 MB 3.7 MB/s eta 0:00:04
#      --- ------------------------------------ 1.0/11.8 MB 3.8 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.2/11.8 MB 3.8 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.4/11.8 MB 3.8 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.5/11.8 MB 3.8 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.8/11.8 MB 3.9 MB/s eta 0:00:03
#      ------ --------------------------------- 2.0/11.8 MB 4.0 MB/s eta 0:00:03
#      ------- -------------------------------- 2.2/11.8 MB 4.1 MB/s eta 0:00:03
#      -------- ------------------------------- 2.5/11.8 MB 4.2 MB/s eta 0:00:03
#      --------- ------------------------------ 2.7/11.8 MB 4.3 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.0/11.8 MB 4.4 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.3/11.8 MB 4.4 MB/s eta 0:00:02
#      ------------ --------------------------- 3.6/11.8 MB 4.5 MB/s eta 0:00:02
#      ------------ --------------------------- 3.8/11.8 MB 4.6 MB/s eta 0:00:02
#      ------------- -------------------------- 4.0/11.8 MB 4.6 MB/s eta 0:00:02
#      -------------- ------------------------- 4.3/11.8 MB 4.7 MB/s eta 0:00:02
#      --------------- ------------------------ 4.6/11.8 MB 4.8 MB/s eta 0:00:02
#      ---------------- ----------------------- 4.9/11.8 MB 4.9 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.2/11.8 MB 5.0 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.3/11.8 MB 4.9 MB/s eta 0:00:02
#      ------------------ --------------------- 5.6/11.8 MB 4.9 MB/s eta 0:00:02
#      ------------------- -------------------- 5.9/11.8 MB 5.0 MB/s eta 0:00:02
#      -------------------- ------------------- 6.2/11.8 MB 5.0 MB/s eta 0:00:02
#      ---------------------- ----------------- 6.5/11.8 MB 5.1 MB/s eta 0:00:02
#      ----------------------- ---------------- 6.8/11.8 MB 5.1 MB/s eta 0:00:01
#      ------------------------ --------------- 7.1/11.8 MB 5.2 MB/s eta 0:00:01
#      ------------------------- -------------- 7.4/11.8 MB 5.2 MB/s eta 0:00:01
#      -------------------------- ------------- 7.7/11.8 MB 5.3 MB/s eta 0:00:01
#      --------------------------- ------------ 8.0/11.8 MB 5.3 MB/s eta 0:00:01
#      ---------------------------- ----------- 8.4/11.8 MB 5.3 MB/s eta 0:00:01
#      ----------------------------- ---------- 8.7/11.8 MB 5.4 MB/s eta 0:00:01
#      ------------------------------ --------- 8.9/11.8 MB 5.4 MB/s eta 0:00:01
#      ------------------------------- -------- 9.2/11.8 MB 5.4 MB/s eta 0:00:01
#      -------------------------------- ------- 9.6/11.8 MB 5.5 MB/s eta 0:00:01
#      --------------------------------- ------ 9.9/11.8 MB 5.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 10.1/11.8 MB 5.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 10.5/11.8 MB 5.6 MB/s eta 0:00:01
#      ------------------------------------ --- 10.7/11.8 MB 5.6 MB/s eta 0:00:01
#      ------------------------------------ --- 10.9/11.8 MB 5.6 MB/s eta 0:00:01
#      ------------------------------------- -- 11.2/11.8 MB 5.7 MB/s eta 0:00:01
#      -------------------------------------- - 11.4/11.8 MB 5.8 MB/s eta 0:00:01
#      -------------------------------------- - 11.5/11.8 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  11.8/11.8 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------- 11.8/11.8 MB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [327 lines of output]
#       C:\Users\Cr4sZ\AppData\Local\Temp\pip-install-8llpvtad\pandas_30180079a8054af083bb7e022816ef53\setup.py:12: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#         import pkg_resources
#       C:\Users\Cr4sZ\AppData\Local\Temp\pip-install-8llpvtad\pandas_30180079a8054af083bb7e022816ef53\setup.py:50: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         _CYTHON_INSTALLED = ver >= LooseVersion(min_cython_ver)
#       Compiling pandas\_libs/algos.pyx because it changed.
#       Compiling pandas\_libs/groupby.pyx because it changed.
#       Compiling pandas\_libs/hashing.pyx because it changed.
#       Compiling pandas\_libs/hashtable.pyx because it changed.
#       Compiling pandas\_libs/index.pyx because it changed.
#       Compiling pandas\_libs/indexing.pyx because it changed.
#       Compiling pandas\_libs/internals.pyx because it changed.
#       Compiling pandas\_libs/interval.pyx because it changed.
#       Compiling pandas\_libs/join.pyx because it changed.
#       Compiling pandas\_libs/lib.pyx because it changed.
#       Compiling pandas\_libs/missing.pyx because it changed.
#       Compiling pandas\_libs/parsers.pyx because it changed.
#       Compiling pandas\_libs/reduction.pyx because it changed.
#       Compiling pandas\_libs/ops.pyx because it changed.
#       Compiling pandas\_libs/properties.pyx because it changed.
#       Compiling pandas\_libs/reshape.pyx because it changed.
#       Compiling pandas\_libs/skiplist.pyx because it changed.
#       Compiling pandas\_libs/sparse.pyx because it changed.
#       Compiling pandas\_libs/tslib.pyx because it changed.
#       Compiling pandas\_libs/tslibs/ccalendar.pyx because it changed.
#       Compiling pandas\_libs/tslibs/conversion.pyx because it changed.
#       Compiling pandas\_libs/tslibs/fields.pyx because it changed.
#       Compiling pandas\_libs/tslibs/frequencies.pyx because it changed.
#       Compiling pandas\_libs/tslibs/nattype.pyx because it changed.
#       Compiling pandas\_libs/tslibs/np_datetime.pyx because it changed.
#       Compiling pandas\_libs/tslibs/offsets.pyx because it changed.
#       Compiling pandas\_libs/tslibs/parsing.pyx because it changed.
#       Compiling pandas\_libs/tslibs/period.pyx because it changed.
#       Compiling pandas\_libs/tslibs/resolution.pyx because it changed.
#       Compiling pandas\_libs/tslibs/strptime.pyx because it changed.
#       Compiling pandas\_libs/tslibs/timedeltas.pyx because it changed.
#       Compiling pandas\_libs/tslibs/timestamps.pyx because it changed.
#       Compiling pandas\_libs/tslibs/timezones.pyx because it changed.
#       Compiling pandas\_libs/testing.pyx because it changed.
#       Compiling pandas\_libs/window.pyx because it changed.
#       Compiling pandas\_libs/writers.pyx because it changed.
#       Compiling pandas\io/sas/sas.pyx because it changed.
#       Compiling pandas\io/msgpack/_packer.pyx because it changed.
#       Compiling pandas\io/msgpack/_unpacker.pyx because it changed.
#       [ 1/39] Cythonizing pandas\_libs/algos.pyx
#       warning: pandas\_libs\algos_take_helper.pxi:89:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:145:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:349:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:405:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:609:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:665:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:869:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:925:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:1129:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:1185:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:1389:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:1445:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:1649:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:1705:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:1909:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:1965:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:2169:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:2225:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:2429:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:2485:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:2689:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:2745:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:2949:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:3005:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:3209:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:3265:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:3469:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:3525:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:3729:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:3785:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:3989:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:4045:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:4249:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:4305:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:4509:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:4565:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:4769:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos_take_helper.pxi:4825:4: The 'IF' statement is deprecated and will be removed in a future Cython version. Consider using runtime conditions or C macros instead. See https://github.com/cython/cython/issues/4310
#       warning: pandas\_libs\algos.pyx:117:42: Unknown type declaration 'bint' in annotation, ignoring
#       [ 2/39] Cythonizing pandas\_libs/groupby.pyx
#       [ 3/39] Cythonizing pandas\_libs/hashing.pyx
#       performance hint: pandas\_libs\hashing.pyx:98:5: Exception check on 'u32to8_le' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'u32to8_le' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'u32to8_le' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashing.pyx:116:5: Exception check on '_sipround' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare '_sipround' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on '_sipround' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashing.pyx:160:21: Exception check after calling '_sipround' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare '_sipround' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on '_sipround' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashing.pyx:171:17: Exception check after calling '_sipround' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare '_sipround' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on '_sipround' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashing.pyx:177:17: Exception check after calling '_sipround' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare '_sipround' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on '_sipround' to allow an error code to be returned.
#       [ 4/39] Cythonizing pandas\_libs/hashtable.pyx
#       performance hint: pandas\_libs\hashtable_class_helper.pxi:19:5: Exception check on 'append_data_float64' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'append_data_float64' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'append_data_float64' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashtable_class_helper.pxi:28:5: Exception check on 'append_data_int64' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'append_data_int64' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'append_data_int64' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashtable_class_helper.pxi:41:5: Exception check on 'append_data_string' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'append_data_string' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'append_data_string' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashtable_class_helper.pxi:54:5: Exception check on 'append_data_uint64' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'append_data_uint64' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'append_data_uint64' to allow an error code to be returned.
#       warning: pandas\_libs\hashtable_class_helper.pxi:1361:22: Assigning to 'char *' from 'const char *' discards const qualifier
#       performance hint: pandas\_libs\hashtable_class_helper.pxi:538:39: Exception check after calling 'append_data_float64' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'append_data_float64' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'append_data_float64' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashtable_class_helper.pxi:651:39: Exception check after calling 'append_data_float64' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'append_data_float64' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'append_data_float64' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashtable_class_helper.pxi:842:38: Exception check after calling 'append_data_uint64' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'append_data_uint64' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'append_data_uint64' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashtable_class_helper.pxi:952:38: Exception check after calling 'append_data_uint64' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'append_data_uint64' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'append_data_uint64' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashtable_class_helper.pxi:1143:37: Exception check after calling 'append_data_int64' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'append_data_int64' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'append_data_int64' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashtable_class_helper.pxi:1256:37: Exception check after calling 'append_data_int64' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'append_data_int64' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'append_data_int64' to allow an error code to be returned.
#       performance hint: pandas\_libs\hashtable.pyx:166:33: Exception check after calling 'append_data_int64' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare 'append_data_int64' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on 'append_data_int64' to allow an error code to be returned.
#       [ 5/39] Cythonizing pandas\_libs/index.pyx
#       [ 6/39] Cythonizing pandas\_libs/indexing.pyx
#       [ 7/39] Cythonizing pandas\_libs/internals.pyx
#       [ 8/39] Cythonizing pandas\_libs/interval.pyx
#       [ 9/39] Cythonizing pandas\_libs/join.pyx
#       [10/39] Cythonizing pandas\_libs/lib.pyx
#       [11/39] Cythonizing pandas\_libs/missing.pyx
#       [12/39] Cythonizing pandas\_libs/ops.pyx
#       [13/39] Cythonizing pandas\_libs/parsers.pyx
#       performance hint: pandas\_libs\parsers.pyx:1714:5: Exception check on '_to_fw_string_nogil' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare '_to_fw_string_nogil' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on '_to_fw_string_nogil' to allow an error code to be returned.
#       warning: pandas\_libs\parsers.pyx:1764:34: Casting a GIL-requiring function into a nogil function circumvents GIL validation
#       performance hint: pandas\_libs\parsers.pyx:1709:27: Exception check after calling '_to_fw_string_nogil' will always require the GIL to be acquired.
#       Possible solutions:
#           1. Declare '_to_fw_string_nogil' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#           2. Use an 'int' return type on '_to_fw_string_nogil' to allow an error code to be returned.
#       performance hint: pandas\_libs\parsers.pyx:1809:42: Exception check after calling 'double_converter' will always require the GIL to be acquired. Declare 'double_converter' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#       performance hint: pandas\_libs\parsers.pyx:1830:38: Exception check after calling 'double_converter' will always require the GIL to be acquired. Declare 'double_converter' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
#       [14/39] Cythonizing pandas\_libs/properties.pyx
#       [15/39] Cythonizing pandas\_libs/reduction.pyx
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#                   object cached_typ=None
#
#               arr = self.arr
#               chunk = self.dummy
#               dummy_buf = chunk.data
#               chunk.data = arr.data
#                    ^
#       ------------------------------------------------------------
#
#       pandas\_libs\reduction.pyx:106:13: Assignment to a read-only property
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#                                                      self.nresults,
#                                                      len(self.dummy))
#                           it = <flatiter>PyArray_IterNew(result)
#
#                       PyArray_SETITEM(result, PyArray_ITER_DATA(it), res)
#                       chunk.data = chunk.data + self.increment
#                            ^
#       ------------------------------------------------------------
#
#       pandas\_libs\reduction.pyx:159:21: Assignment to a read-only property
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#                   if hasattr(e, 'args'):
#                       e.args = e.args + (i,)
#                   raise
#               finally:
#                   # so we don't free the wrong memory
#                   chunk.data = dummy_buf
#                        ^
#       ------------------------------------------------------------
#
#       pandas\_libs\reduction.pyx:167:17: Assignment to a read-only property
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#                   if hasattr(e, 'args'):
#                       e.args = e.args + (i,)
#                   raise
#               finally:
#                   # so we don't free the wrong memory
#                   chunk.data = dummy_buf
#                        ^
#       ------------------------------------------------------------
#
#       pandas\_libs\reduction.pyx:167:17: Assignment to a read-only property
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#
#               self.orig_data = self.buf.data
#               self.orig_len = self.buf.shape[0]
#               self.orig_stride = self.buf.strides[0]
#
#               self.buf.data = self.values.data
#                       ^
#       ------------------------------------------------------------
#
#       pandas\_libs\reduction.pyx:469:16: Assignment to a read-only property
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#
#               self.buf.data = self.values.data
#               self.buf.strides[0] = self.stride
#
#           cpdef advance(self, Py_ssize_t k):
#               self.buf.data = <char*>self.buf.data + self.stride * k
#                       ^
#       ------------------------------------------------------------
#
#       pandas\_libs\reduction.pyx:473:16: Assignment to a read-only property
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#
#           cdef move(self, int start, int end):
#               """
#               For slicing
#               """
#               self.buf.data = self.values.data + self.stride * start
#                       ^
#       ------------------------------------------------------------
#
#       pandas\_libs\reduction.pyx:479:16: Assignment to a read-only property
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#               self.buf.shape[0] = length
#
#           cpdef reset(self):
#
#               self.buf.shape[0] = self.orig_len
#               self.buf.data = self.orig_data
#                       ^
#       ------------------------------------------------------------
#
#       pandas\_libs\reduction.pyx:488:16: Assignment to a read-only property
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#               # move blocks
#               for i in range(self.nblocks):
#                   arr = self.blocks[i]
#
#                   # axis=1 is the frame's axis=0
#                   arr.data = self.base_ptrs[i] + arr.strides[1] * start
#                      ^
#       ------------------------------------------------------------
#
#       pandas\_libs\reduction.pyx:598:15: Assignment to a read-only property
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#               # reset blocks
#               for i in range(self.nblocks):
#                   arr = self.blocks[i]
#
#                   # axis=1 is the frame's axis=0
#                   arr.data = self.base_ptrs[i]
#                      ^
#       ------------------------------------------------------------
#
#       pandas\_libs\reduction.pyx:616:15: Assignment to a read-only property
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\Cr4sZ\AppData\Local\Temp\pip-install-8llpvtad\pandas_30180079a8054af083bb7e022816ef53\setup.py", line 735, in <module>
#           ext_modules=maybe_cythonize(extensions, compiler_directives=directives),
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Cr4sZ\AppData\Local\Temp\pip-install-8llpvtad\pandas_30180079a8054af083bb7e022816ef53\setup.py", line 489, in maybe_cythonize
#           return cythonize(extensions, *args, **kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "c:\Users\Cr4sZ\anaconda3\Lib\site-packages\Cython\Build\Dependencies.py", line 1154, in cythonize
#           cythonize_one(*args)
#         File "c:\Users\Cr4sZ\anaconda3\Lib\site-packages\Cython\Build\Dependencies.py", line 1321, in cythonize_one
#           raise CompileError(None, pyx_file)
#       Cython.Compiler.Errors.CompileError: pandas\_libs/reduction.pyx
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 # not being used now - mounting google drive to be able to access files in the folder
#       2 get_ipython().run_line_magic('pip', 'install google-colab')
# ----> 3 from google.colab import drive
#       4 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import numpy as np
X = np.load('/content/drive/MyDrive/Final Project/exploring action recognition/X_2_without_facemesh.npy')
y = np.load('/content/drive/MyDrive/Final Project/exploring action recognition/y_2_without_facemesh.npy')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (5, 3)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
import os

# %%
log_dir = os.path.join('Logs')

# %%
tb_callback = TensorBoard(log_dir=log_dir)

# %%
coeficient=0.5
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='tanh', input_shape=(30,258)))
model.add(LSTM(int(128*coeficient), return_sequences=True, activation='tanh'))
model.add(LSTM(int(64*coeficient), return_sequences=False, activation='tanh'))
model.add(Dense(int(64*coeficient), activation='tanh'))
model.add(Dense(32, activation='tanh'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])
# Out:
# Epoch 1/200
# 3/3 [==============================] - 11s 58ms/step - loss: 1.0435 - categorical_accuracy: 0.3529
# Epoch 2/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.8100 - categorical_accuracy: 0.6471
# Epoch 3/200
# 3/3 [==============================] - 0s 67ms/step - loss: 0.6475 - categorical_accuracy: 0.7647
# Epoch 4/200
# 3/3 [==============================] - 0s 57ms/step - loss: 0.5500 - categorical_accuracy: 0.8471
# Epoch 5/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.4849 - categorical_accuracy: 0.8235
# Epoch 6/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.4341 - categorical_accuracy: 0.8118
# Epoch 7/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3996 - categorical_accuracy: 0.8353
# Epoch 8/200
# 3/3 [==============================] - 0s 66ms/step - loss: 0.3604 - categorical_accuracy: 0.8471
# Epoch 9/200
# 3/3 [==============================] - 0s 77ms/step - loss: 0.3336 - categorical_accuracy: 0.8706
# Epoch 10/200
# 3/3 [==============================] - 0s 69ms/step - loss: 0.2993 - categorical_accuracy: 0.8706
# Epoch 11/200
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2535 - categorical_accuracy: 0.8824
# Epoch 12/200
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2815 - categorical_accuracy: 0.8941
# Epoch 13/200
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2720 - categorical_accuracy: 0.9059
# Epoch 14/200
# 3/3 [==============================] - 0s 77ms/step - loss: 0.3186 - categorical_accuracy: 0.8706
# Epoch 15/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3292 - categorical_accuracy: 0.8588
# Epoch 16/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.1881 - categorical_accuracy: 0.9412
# Epoch 17/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1890 - categorical_accuracy: 0.9412
# Epoch 18/200
# 3/3 [==============================] - 0s 53ms/step - loss: 0.1550 - categorical_accuracy: 0.9412
# Epoch 19/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2105 - categorical_accuracy: 0.9294
# Epoch 20/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.6079 - categorical_accuracy: 0.7882
# Epoch 21/200
# 3/3 [==============================] - 0s 63ms/step - loss: 0.9509 - categorical_accuracy: 0.6471
# Epoch 22/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.6544 - categorical_accuracy: 0.6588
# Epoch 23/200
# 3/3 [==============================] - 0s 70ms/step - loss: 0.4985 - categorical_accuracy: 0.7059
# Epoch 24/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4746 - categorical_accuracy: 0.6588
# Epoch 25/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.4764 - categorical_accuracy: 0.6588
# Epoch 26/200
# 3/3 [==============================] - 0s 67ms/step - loss: 0.4484 - categorical_accuracy: 0.7294
# Epoch 27/200
# 3/3 [==============================] - 0s 104ms/step - loss: 0.4294 - categorical_accuracy: 0.7529
# Epoch 28/200
# 3/3 [==============================] - 0s 96ms/step - loss: 0.3871 - categorical_accuracy: 0.8000
# Epoch 29/200
# 3/3 [==============================] - 0s 104ms/step - loss: 0.3098 - categorical_accuracy: 0.8353
# Epoch 30/200
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2800 - categorical_accuracy: 0.9176
# Epoch 31/200
# 3/3 [==============================] - 0s 99ms/step - loss: 0.2352 - categorical_accuracy: 0.9059
# Epoch 32/200
# 3/3 [==============================] - 0s 96ms/step - loss: 0.2243 - categorical_accuracy: 0.9176
# Epoch 33/200
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2941 - categorical_accuracy: 0.8941
# Epoch 34/200
# 3/3 [==============================] - 0s 101ms/step - loss: 0.2254 - categorical_accuracy: 0.9059
# Epoch 35/200
# 3/3 [==============================] - 0s 110ms/step - loss: 0.2047 - categorical_accuracy: 0.9294
# Epoch 36/200
# 3/3 [==============================] - 0s 105ms/step - loss: 0.2240 - categorical_accuracy: 0.9059
# Epoch 37/200
# 3/3 [==============================] - 0s 106ms/step - loss: 0.2343 - categorical_accuracy: 0.9176
# Epoch 38/200
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2060 - categorical_accuracy: 0.9059
# Epoch 39/200
# 3/3 [==============================] - 0s 93ms/step - loss: 0.2062 - categorical_accuracy: 0.9176
# Epoch 40/200
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1792 - categorical_accuracy: 0.9176
# Epoch 41/200
# 3/3 [==============================] - 0s 85ms/step - loss: 0.2278 - categorical_accuracy: 0.9059
# Epoch 42/200
# 3/3 [==============================] - 0s 73ms/step - loss: 0.1262 - categorical_accuracy: 0.9765
# Epoch 43/200
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1445 - categorical_accuracy: 0.9529
# Epoch 44/200
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1464 - categorical_accuracy: 0.9412
# Epoch 45/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1077 - categorical_accuracy: 0.9647
# Epoch 46/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0648 - categorical_accuracy: 0.9882
# Epoch 47/200
# 3/3 [==============================] - 0s 72ms/step - loss: 0.1065 - categorical_accuracy: 0.9647
# Epoch 48/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0534 - categorical_accuracy: 1.0000
# Epoch 49/200
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0605 - categorical_accuracy: 0.9765
# Epoch 50/200
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0530 - categorical_accuracy: 0.9882
# Epoch 51/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1698 - categorical_accuracy: 0.9529
# Epoch 52/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1092 - categorical_accuracy: 0.9647
# Epoch 53/200
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1213 - categorical_accuracy: 0.9529
# Epoch 54/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2029 - categorical_accuracy: 0.9176
# Epoch 55/200
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0732 - categorical_accuracy: 0.9765
# Epoch 56/200
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0742 - categorical_accuracy: 0.9882
# Epoch 57/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0897 - categorical_accuracy: 0.9647
# Epoch 58/200
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0728 - categorical_accuracy: 0.9765
# Epoch 59/200
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0611 - categorical_accuracy: 0.9882
# Epoch 60/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0643 - categorical_accuracy: 0.9882
# Epoch 61/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0966 - categorical_accuracy: 0.9765
# Epoch 62/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0294 - categorical_accuracy: 1.0000
# Epoch 63/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0360 - categorical_accuracy: 1.0000
# Epoch 64/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0459 - categorical_accuracy: 0.9765
# Epoch 65/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0221 - categorical_accuracy: 1.0000
# Epoch 66/200
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0222 - categorical_accuracy: 1.0000
# Epoch 67/200
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0182 - categorical_accuracy: 1.0000
# Epoch 68/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0146 - categorical_accuracy: 1.0000
# Epoch 69/200
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0146 - categorical_accuracy: 1.0000
# Epoch 70/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0136 - categorical_accuracy: 1.0000
# Epoch 71/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0107 - categorical_accuracy: 1.0000
# Epoch 72/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0104 - categorical_accuracy: 1.0000
# Epoch 73/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0100 - categorical_accuracy: 1.0000
# Epoch 74/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0093 - categorical_accuracy: 1.0000
# Epoch 75/200
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0087 - categorical_accuracy: 1.0000
# Epoch 76/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0084 - categorical_accuracy: 1.0000
# Epoch 77/200
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0081 - categorical_accuracy: 1.0000
# Epoch 78/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0078 - categorical_accuracy: 1.0000
# Epoch 79/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0075 - categorical_accuracy: 1.0000
# Epoch 80/200
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0073 - categorical_accuracy: 1.0000
# Epoch 81/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0070 - categorical_accuracy: 1.0000
# Epoch 82/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 83/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0066 - categorical_accuracy: 1.0000
# Epoch 84/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0064 - categorical_accuracy: 1.0000
# Epoch 85/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0063 - categorical_accuracy: 1.0000
# Epoch 86/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0061 - categorical_accuracy: 1.0000
# Epoch 87/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0060 - categorical_accuracy: 1.0000
# Epoch 88/200
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0058 - categorical_accuracy: 1.0000
# Epoch 89/200
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0057 - categorical_accuracy: 1.0000
# Epoch 90/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0055 - categorical_accuracy: 1.0000
# Epoch 91/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0054 - categorical_accuracy: 1.0000
# Epoch 92/200
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0053 - categorical_accuracy: 1.0000
# Epoch 93/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0052 - categorical_accuracy: 1.0000
# Epoch 94/200
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0051 - categorical_accuracy: 1.0000
# Epoch 95/200
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0050 - categorical_accuracy: 1.0000
# Epoch 96/200
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0049 - categorical_accuracy: 1.0000
# Epoch 97/200
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0048 - categorical_accuracy: 1.0000
# Epoch 98/200
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0047 - categorical_accuracy: 1.0000
# Epoch 99/200
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0046 - categorical_accuracy: 1.0000
# Epoch 100/200
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0045 - categorical_accuracy: 1.0000
# Epoch 101/200
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0044 - categorical_accuracy: 1.0000
# Epoch 102/200
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0043 - categorical_accuracy: 1.0000
# Epoch 103/200
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0043 - categorical_accuracy: 1.0000
# Epoch 104/200
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0042 - categorical_accuracy: 1.0000
# Epoch 105/200
# 3/3 [==============================] - 0s 108ms/step - loss: 0.0041 - categorical_accuracy: 1.0000
# Epoch 106/200
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0040 - categorical_accuracy: 1.0000
# Epoch 107/200
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0040 - categorical_accuracy: 1.0000
# Epoch 108/200
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0039 - categorical_accuracy: 1.0000
# Epoch 109/200
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0038 - categorical_accuracy: 1.0000
# Epoch 110/200
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0038 - categorical_accuracy: 1.0000
# Epoch 111/200
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0037 - categorical_accuracy: 1.0000
# Epoch 112/200
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 113/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 114/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 115/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0035 - categorical_accuracy: 1.0000
# Epoch 116/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 117/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 118/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 119/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 120/200
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 121/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 122/200
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 123/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 124/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 125/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 126/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 127/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 128/200
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 129/200
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 130/200
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 131/200
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0028 - categorical_accuracy: 1.0000
# Epoch 132/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 133/200
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 134/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0027 - categorical_accuracy: 1.0000
# Epoch 135/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0026 - categorical_accuracy: 1.0000
# Epoch 136/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0026 - categorical_accuracy: 1.0000
# Epoch 137/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0026 - categorical_accuracy: 1.0000
# Epoch 138/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 139/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 140/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 141/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 142/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 143/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 144/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 145/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 146/200
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 147/200
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 148/200
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 149/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 150/200
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 151/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 152/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0022 - categorical_accuracy: 1.0000
# Epoch 153/200
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 154/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 155/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 156/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 157/200
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 158/200
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 159/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 160/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 161/200
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 162/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 163/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 164/200
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 165/200
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 166/200
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 167/200
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 168/200
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 169/200
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 170/200
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 171/200
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 172/200
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 173/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 174/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 175/200
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 176/200
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 177/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 178/200
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 179/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 180/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 181/200
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 182/200
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 183/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 184/200
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 185/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 186/200
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 187/200
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 188/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 189/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 190/200
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 191/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 192/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 193/200
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 194/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 195/200
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 196/200
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 197/200
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 198/200
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 199/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 200/200
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-2d4eae74e1a9> in <cell line: 1>()
# ----> 1 model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (None, 30, 64)            82688
#
#  lstm_12 (LSTM)              (None, 30, 64)            33024
#
#  lstm_13 (LSTM)              (None, 32)                12416
#
#  dense_9 (Dense)             (None, 32)                1056
#
#  dense_10 (Dense)            (None, 32)                1056
#
#  dense_11 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 130339 (509.14 KB)
# Trainable params: 130339 (509.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 8. Make predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
actions[np.argmax(res[4])]
# Out:
# 'thanks'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'thanks'

# %% [markdown]
# ## 9. Save weights

# %%
model.save("2_without_facemesh.keras")

# %% [markdown]
# ## 10. Evaluation using confusion matrix and accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 42ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[0., 5.],
#         [0., 0.]],
#
#        [[1., 0.],
#         [4., 0.]],
#
#        [[4., 0.],
#         [1., 0.]]])

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.0

# %%
accuracy_score
