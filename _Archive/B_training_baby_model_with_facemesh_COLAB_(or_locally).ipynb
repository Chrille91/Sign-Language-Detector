# %% [markdown]
# # Sign Language Detection Project

# %%
# %pip uninstall protobuf -y
# %pip install protobuf

# %%
# %pip install mediapipe==0.8.8.1
# versions: 0.9.1.0, 0.9.2.1, 0.9.3.0, 0.10.0, 0.10.1, 0.10.2, 0.10.3, 0.10.5, 0.10.7, 0.10.8, 0.10.9, 0.10.10, 0.10.11, 0.10.13, 0.10.14)

# %%
# tensorflow-gpu 
# %pip install mediapipe sklearn matplotlib
# %pip install tensorflow==2.10.0 mediapipe scikit-learn matplotlib
# %pip install mediapipe scikit-learn matplotlib

# %%
# %pip install tensorflow[and-cuda]

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
# need to launch VS Code as Administrator to use mediapipe?
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
# from tensorflow.keras.applications import ResNet50 
from sklearn.model_selection import train_test_split


tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
print(tf.__version__)
# Out:
# 2.13.1

# %%
# ========= INPUT 1 =========

# Actions that we try to detect
# actions = np.array(['yes', 'no', 'PeaceAmongWorlds'])
actions = np.array(['Hi', 'Yes', 'No', 'ThankYou', 'ILoveYou', 'background', 'NoHands'])

# number of videos/sequences worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

DATA_PATH = os.path.join('MP_Data')

# training with facemesh or not
facemesh_included = False

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
label_map = {label:num for num, label in enumerate(actions)}
label_map
# Out:
# {'Hi': 0,
#  'Yes': 1,
#  'No': 2,
#  'ThankYou': 3,
#  'ILoveYou': 4,
#  'background': 5,
#  'NoHands': 6}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            frame = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            if facemesh_included == False:
                frame = frame[:258] # get only the first 258 points, ie delete facemesh data
            window.append(frame)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)
# Out:
# (210, 30, 258)

# %%
# not being used now - mounting google drive to be able to access files in the folder
# from google.colab import drive
# drive.mount('/content/drive/MyDrive')

# %%
np.save(os.path.join(DATA_PATH,'X'), X)
np.save(os.path.join(DATA_PATH,'y'), y)

# %%
# the paths need to be updated accordingly
X = np.load(os.path.join(DATA_PATH,'X.npy'))
y = np.load(os.path.join(DATA_PATH,'y.npy'))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
log_dir = os.path.join('Logs')

# %%
# ========= INPUT 2 =========

neural_multiplicator = 8
activation_function = 'tanh'
camera_index = 0
number_of_classes = actions.shape[0]

if facemesh_included:
  number_of_keypoints = 1662 # 258 if no facemesh, 1662 if facemesh is included
  coefficient = 1 # if coefficient is 1, the model structure is the same as it is in the original model by Nick
  weights_name = "weights_w_facemesh_NM" + str(neural_multiplicator)
else:
  number_of_keypoints = 258 # 258 if no facemesh, 1662 if facemesh is included
  coefficient = 0.5 # coefficient 0.5 means that the number of neurons in 2nd, the 3rd and the 4th layer will be half - so as to account for the smaller input shape WHEN FACEMESH is REMOVED
  weights_name = "weights_wo_facemesh_NM" + str(neural_multiplicator)


# simplest kind of a Keras model for neural networks that are just composed of a stack of layers where each layer has exactly one input tensor and one output tensor.
model = Sequential()
# Long Short-Term Memory (LSTM) layers which are a type of recurrent neural network (RNN) suitable for sequence prediction problems
model.add(LSTM(64, return_sequences=True, activation=activation_function, input_shape=(30, number_of_keypoints)))
model.add(LSTM(int(128*coefficient*neural_multiplicator), return_sequences=True, activation=activation_function))
model.add(LSTM(int(64*coefficient*neural_multiplicator), return_sequences=False, activation=activation_function))
# These layers further process the data into a more abstract representation. They are typical feed-forward layers.
model.add(Dense(int(64*coefficient*neural_multiplicator), activation=activation_function))
model.add(Dense(32*neural_multiplicator, activation=activation_function))
 #output layer that predicts the keypoints; each node in this layer will output a value between 0 and 1, indicating the presence of each keypoint/action
model.add(Dense(number_of_classes, activation='softmax')) 

# reLU = Rectified Linear Activation Function: returns 0 if it receives any negative input, but for any positive value x it returns that value back.  It helps the model to account for non-linearity.
# Sigmoid: Outputs a value between 0 and 1, making it suitable for binary classification or multilabel classification tasks where each label is predicted independently.

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  
    patience=10,          
    restore_best_weights=True  
)

tb_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir,
    histogram_freq=0,
    write_graph=True,
    write_images=False,
    write_steps_per_second=False,
    update_freq="epoch",
    profile_batch=0,
    embeddings_freq=0,
    embeddings_metadata=None,
)

# %%
"""
tb_callback = TensorBoard(log_dir=log_dir)
log_dir is the path of the directory where to save the log files to be parsed by TensorBoard.
TensorBoard is a visualization tool provided with TensorFlow. This callback logs events for TensorBoard, including:
Metrics summary plots, Training graph visualization, Activation histograms, Sampled profiling
"""
# hist = model.fit(X_train, y_train, epochs=2000, validation_data=val_data, callbacks=[early_stopping])
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.8185 - categorical_accuracy: 0.2814WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 5s 154ms/step - loss: 1.8185 - categorical_accuracy: 0.2814
# Epoch 2/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.2010 - categorical_accuracy: 0.5829WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 155ms/step - loss: 1.2010 - categorical_accuracy: 0.5829
# Epoch 3/2000
# 7/7 [==============================] - ETA: 0s - loss: 0.9670 - categorical_accuracy: 0.5377WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 157ms/step - loss: 0.9670 - categorical_accuracy: 0.5377
# Epoch 4/2000
# 7/7 [==============================] - ETA: 0s - loss: 0.9241 - categorical_accuracy: 0.6734WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 158ms/step - loss: 0.9241 - categorical_accuracy: 0.6734
# Epoch 5/2000
# 7/7 [==============================] - ETA: 0s - loss: 0.8874 - categorical_accuracy: 0.6482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 158ms/step - loss: 0.8874 - categorical_accuracy: 0.6482
# Epoch 6/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.0588 - categorical_accuracy: 0.6181WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 157ms/step - loss: 1.0588 - categorical_accuracy: 0.6181
# Epoch 7/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.0023 - categorical_accuracy: 0.5327WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 159ms/step - loss: 1.0023 - categorical_accuracy: 0.5327
# Epoch 8/2000
# 7/7 [==============================] - ETA: 0s - loss: 0.8592 - categorical_accuracy: 0.6583WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 158ms/step - loss: 0.8592 - categorical_accuracy: 0.6583
# Epoch 9/2000
# 7/7 [==============================] - ETA: 0s - loss: 0.7121 - categorical_accuracy: 0.6985WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 167ms/step - loss: 0.7121 - categorical_accuracy: 0.6985
# Epoch 10/2000
# 7/7 [==============================] - ETA: 0s - loss: 0.8288 - categorical_accuracy: 0.6683WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 166ms/step - loss: 0.8288 - categorical_accuracy: 0.6683
# Epoch 11/2000
# 7/7 [==============================] - ETA: 0s - loss: 0.6900 - categorical_accuracy: 0.6935WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 169ms/step - loss: 0.6900 - categorical_accuracy: 0.6935
# Epoch 12/2000
# 7/7 [==============================] - ETA: 0s - loss: 0.7640 - categorical_accuracy: 0.6583WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 169ms/step - loss: 0.7640 - categorical_accuracy: 0.6583
# Epoch 13/2000
# 7/7 [==============================] - ETA: 0s - loss: 0.7492 - categorical_accuracy: 0.6231WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 172ms/step - loss: 0.7492 - categorical_accuracy: 0.6231
# Epoch 14/2000
# 7/7 [==============================] - ETA: 0s - loss: 0
ARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 167ms/step - loss: 0.0146 - categorical_accuracy: 0.9950
# ...
# 7/7 [==============================] - ETA: 0s - loss: 1.6306e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 163ms/step - loss: 1.6306e-05 - categorical_accuracy: 1.0000
# Epoch 549/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.6237e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 167ms/step - loss: 1.6237e-05 - categorical_accuracy: 1.0000
# Epoch 550/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.6168e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 165ms/step - loss: 1.6168e-05 - categorical_accuracy: 1.0000
# Epoch 551/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.6091e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 165ms/step - loss: 1.6091e-05 - categorical_accuracy: 1.0000
# Epoch 552/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.6020e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 158ms/step - loss: 1.6020e-05 - categorical_accuracy: 1.0000
# Epoch 553/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5949e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 163ms/step - loss: 1.5949e-05 - categorical_accuracy: 1.0000
# Epoch 554/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5882e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 161ms/step - loss: 1.5882e-05 - categorical_accuracy: 1.0000
# Epoch 555/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5813e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 184ms/step - loss: 1.5813e-05 - categorical_accuracy: 1.0000
# Epoch 556/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5741e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 180ms/step - loss: 1.5741e-05 - categorical_accuracy: 1.0000
# Epoch 557/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5678e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 171ms/step - loss: 1.5678e-05 - categorical_accuracy: 1.0000
# Epoch 558/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5605e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 162ms/step - loss: 1.5605e-05 - categorical_accuracy: 1.0000
# Epoch 559/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5528e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 166ms/step - loss: 1.5528e-05 - categorical_accuracy: 1.0000
# Epoch 560/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5456e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 167ms/step - loss: 1.5456e-05 - categorical_accuracy: 1.0000
# Epoch 561/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5386e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 164ms/step - loss: 1.5386e-05 - categorical_accuracy: 1.0000
# Epoch 562/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5317e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 170ms/step - loss: 1.5317e-05 - categorical_accuracy: 1.0000
# Epoch 563/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5249e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 162ms/step - loss: 1.5249e-05 - categorical_accuracy: 1.0000
# Epoch 564/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5174e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 167ms/step - loss: 1.5174e-05 - categorical_accuracy: 1.0000
# Epoch 565/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5096e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 181ms/step - loss: 1.5096e-05 - categorical_accuracy: 1.0000
# Epoch 566/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.5030e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 176ms/step - loss: 1.5030e-05 - categorical_accuracy: 1.0000
# Epoch 567/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.4964e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 168ms/step - loss: 1.4964e-05 - categorical_accuracy: 1.0000
# Epoch 568/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.4909e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 165ms/step - loss: 1.4909e-05 - categorical_accuracy: 1.0000
# Epoch 569/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.4834e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 166ms/step - loss: 1.4834e-05 - categorical_accuracy: 1.0000
# Epoch 570/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.4766e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 164ms/step - loss: 1.4766e-05 - categorical_accuracy: 1.0000
# Epoch 571/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.4701e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 171ms/step - loss: 1.4701e-05 - categorical_accuracy: 1.0000
# Epoch 572/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.4633e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 178ms/step - loss: 1.4633e-05 - categorical_accuracy: 1.0000
# Epoch 573/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.4571e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 187ms/step - loss: 1.4571e-05 - categorical_accuracy: 1.0000
# Epoch 574/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.4502e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 172ms/step - loss: 1.4502e-05 - categorical_accuracy: 1.0000
# Epoch 575/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.4436e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 176ms/step - loss: 1.4436e-05 - categorical_accuracy: 1.0000
# Epoch 576/2000
# 7/7 [==============================] - ETA: 0s - loss: 1.4376e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 7/7 [==============================] - 1s 175ms/step - loss: 1.4376e-05 - categorical_accuracy: 1.0000
# Epoch 577/2000
# 2/7 [=======>......................] - ETA: 0s - loss: 1.2522e-05 - categorical_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[186], line 8
#       6 val_data = 'val_loss'
#       7 # model.fit(X_train, y_train, epochs=2000, validation_data=val_data, callbacks=[early_stopping])
# ----> 8 model.fit(X_train, y_train, epochs=2000, callbacks=[early_stopping])
#
# File c:\Users\Cr4sZ\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Cr4sZ\anaconda3\Lib\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File c:\Users\Cr4sZ\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Cr4sZ\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Cr4sZ\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File c:\Users\Cr4sZ\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\Cr4sZ\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Cr4sZ\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File c:\Users\Cr4sZ\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File c:\Users\Cr4sZ\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_21 (LSTM)              (None, 30, 64)            82688
#
#  lstm_22 (LSTM)              (None, 30, 512)           1181696
#
#  lstm_23 (LSTM)              (None, 256)               787456
#
#  dense_21 (Dense)            (None, 256)               65792
#
#  dense_22 (Dense)            (None, 256)               65792
#
#  dense_23 (Dense)            (None, 7)                 1799
#
# =================================================================
# Total params: 2185223 (8.34 MB)
# Trainable params: 2185223 (8.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 8. Make predictions

# %%
res = model.predict(X_test)
correct_count = 0
for i in range(len(res)):
  prediction = actions[np.argmax(res[i])]
  actual = actions[np.argmax(res[i])]
  if prediction == actual:
    correct_count += 1
  print("prediction: ", prediction)
  print("actual    : ", actual)
  print("~"*30)
print("~"*30)
print("accuracy on x_test: ", correct_count/len(res)*100, "%")
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
actions[np.argmax(res[0])]
# Out:
# 'Yes'

# %% [markdown]
# ## 9. Save weights

# %%
model.save(weights_name + ".keras")

# %% [markdown]
# ## 10. Evaluation using confusion matrix and accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_train)
# Out:
# 7/7 [==============================] - 1s 78ms/step

# %%
ytrue = np.argmax(y_train, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Confusion Matrix = True Positive, True Negative, False Positive, False Negative
# identify which gestures are frequently misclassified as others, providing insights into how the gestures overlap or are confused by the model
# Out:
# array([[[169,   0],
#         [  0,  30]],
#
#        [[172,   0],
#         [  0,  27]],
#
#        [[170,   0],
#         [  0,  29]],
#
#        [[169,   0],
#         [  0,  30]],
#
#        [[173,   0],
#         [  0,  26]],
#
#        [[170,   0],
#         [  0,  29]],
#
#        [[171,   0],
#         [  0,  28]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# # ToDo
# 1. ~~Improve Accuracy~~
#     - ~~train for more epochs (often: more accuracy, but might lead to overfitting)~~
#     - ~~fine-tune hyperparameters~~
# 2. Integrate validation data set
# 3. implement image manipulations
# 4. put model parameters like neural multiplicator into config file (because used in B and C)
# 5. Integrate model visualizations from Nick's tutorial
# 6. Integrate TensorBoard visualization
# 7. integrate "if facemesh" into def extract_keypoints(results)
