# %%
import numpy as np
import os
from pathlib import Path

# Define the path where keypoints are stored
AUGMENTED_KEYPOINTS_PATH = "augmentation_keypoints/bread"  # Directory where augmented keypoints are stored

def check_keypoints(npy_path):
    keypoints = np.load(npy_path)
    if np.all(keypoints == 0):
        return True
    return False

def main():
    print("Checking for .npy files with all zero keypoints...")
    # Get all .npy files from the augmented keypoints directory
    npy_files = list(Path(AUGMENTED_KEYPOINTS_PATH).rglob("*.npy"))

    if not npy_files:
        print(f"No .npy files found in {AUGMENTED_KEYPOINTS_PATH}.")
        return

    all_zero_files = []

    # Loop through each .npy file
    for npy_file in npy_files:
        print(f"Checking {npy_file}...")
        if check_keypoints(npy_file):
            all_zero_files.append(npy_file)

    if all_zero_files:
        print("The following .npy files contain only zeros:")
        for file in all_zero_files:
            print(file)
    else:
        print("All .npy files contain valid keypoints.")

if __name__ == "__main__":
    main()
# Out:
# Checking for .npy files with all zero keypoints...
# Checking augmentation_keypoints\bread\0\GaussianBlur\0.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\1.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\10.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\11.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\12.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\13.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\14.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\15.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\16.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\17.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\18.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\19.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\2.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\20.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\21.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\22.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\23.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\24.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\25.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\26.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\27.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\28.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\29.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\3.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\4.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\5.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\6.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\7.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\8.npy...
# Checking augmentation_keypoints\bread\0\GaussianBlur\9.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\0.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\1.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\10.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\11.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\12.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\13.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\14.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\15.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\16.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\17.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\18.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\19.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\2.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\20.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\21.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\22.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\23.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\24.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\25.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\26.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\27.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\28.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\29.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\3.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\4.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\5.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\6.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\7.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\8.npy...
# Checking augmentation_keypoints\bread\0\HorizontalFlip\9.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\0.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\1.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\10.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\11.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\12.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\13.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\14.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\15.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\16.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\17.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\18.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\19.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\2.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\20.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\21.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\22.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\23.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\24.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\25.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\26.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\27.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\28.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\29.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\3.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\4.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\5.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\6.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\7.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\8.npy...
# Checking augmentation_keypoints\bread\0\RandomResize\9.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\0.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\1.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\10.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\11.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\12.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\13.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\14.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\15.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\16.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\17.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\18.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\19.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\2.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\20.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\21.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\22.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\23.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\24.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\25.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\26.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\27.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\28.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\29.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\3.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\4.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\5.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\6.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\7.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\8.npy...
# Checking augmentation_keypoints\bread\0\RandomRotate\9.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\0.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\1.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\10.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\11.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\12.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\13.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\14.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\15.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\16.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\17.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\18.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\19.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\2.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\20.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\21.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\22.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\23.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\24.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\25.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\26.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\27.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\28.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\29.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\3.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\4.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\5.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\6.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\7.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\8.npy...
# Checking augmentation_keypoints\bread\0\RandomTranslate\9.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\0.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\1.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\10.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\11.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\12.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\13.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\14.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\15.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\16.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\17.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\18.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\19.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\2.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\20.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\21.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\22.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\23.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\24.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\25.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\26.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\27.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\28.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\29.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\3.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\4.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\5.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\6.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\7.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\8.npy...
# Checking augmentation_keypoints\bread\1\GaussianBlur\9.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\0.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\1.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\10.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\11.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\12.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\13.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\14.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\15.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\16.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\17.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\18.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\19.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\2.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\20.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\21.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\22.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\23.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\24.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\25.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\26.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\27.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\28.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\29.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\3.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\4.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\5.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\6.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\7.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\8.npy...
# Checking augmentation_keypoints\bread\1\HorizontalFlip\9.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\0.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\1.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\10.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\11.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\12.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\13.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\14.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\15.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\16.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\17.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\18.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\19.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\2.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\20.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\21.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\22.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\23.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\24.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\25.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\26.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\27.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\28.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\29.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\3.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\4.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\5.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\6.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\7.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\8.npy...
# Checking augmentation_keypoints\bread\1\RandomResize\9.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\0.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\1.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\10.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\11.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\12.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\13.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\14.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\15.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\16.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\17.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\18.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\19.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\2.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\20.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\21.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\22.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\23.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\24.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\25.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\26.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\27.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\28.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\29.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\3.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\4.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\5.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\6.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\7.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\8.npy...
# Checking augmentation_keypoints\bread\1\RandomRotate\9.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\0.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\1.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\10.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\11.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\12.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\13.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\14.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\15.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\16.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\17.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\18.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\19.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\2.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\20.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\21.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\22.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\23.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\24.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\25.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\26.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\27.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\28.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\29.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\3.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\4.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\5.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\6.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\7.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\8.npy...
# Checking augmentation_keypoints\bread\1\RandomTranslate\9.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\0.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\1.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\10.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\11.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\12.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\13.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\14.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\15.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\16.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\17.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\18.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\19.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\2.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\20.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\21.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\22.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\23.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\24.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\25.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\26.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\27.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\28.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\29.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\3.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\4.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\5.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\6.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\7.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\8.npy...
# Checking augmentation_keypoints\bread\10\GaussianBlur\9.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\0.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\1.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\10.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\11.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\12.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\13.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\14.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\15.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\16.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\17.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\18.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\19.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\2.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\20.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\21.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\22.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\23.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\24.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\25.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\26.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\27.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\28.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\29.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\3.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\4.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\5.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\6.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\7.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\8.npy...
# Checking augmentation_keypoints\bread\10\HorizontalFlip\9.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\0.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\1.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\10.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\11.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\12.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\13.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\14.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\15.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\16.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\17.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\18.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\19.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\2.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\20.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\21.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\22.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\23.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\24.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\25.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\26.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\27.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\28.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\29.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\3.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\4.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\5.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\6.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\7.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\8.npy...
# Checking augmentation_keypoints\bread\10\RandomResize\9.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\0.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\1.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\10.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\11.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\12.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\13.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\14.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\15.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\16.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\17.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\18.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\19.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\2.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\20.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\21.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\22.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\23.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\24.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\25.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\26.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\27.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\28.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\29.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\3.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\4.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\5.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\6.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\7.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\8.npy...
# Checking augmentation_keypoints\bread\10\RandomRotate\9.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\0.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\1.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\10.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\11.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\12.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\13.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\14.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\15.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\16.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\17.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\18.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\19.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\2.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\20.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\21.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\22.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\23.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\24.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\25.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\26.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\27.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\28.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\29.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\3.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\4.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\5.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\6.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\7.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\8.npy...
# Checking augmentation_keypoints\bread\10\RandomTranslate\9.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\0.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\1.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\10.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\11.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\12.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\13.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\14.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\15.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\16.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\17.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\18.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\19.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\2.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\20.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\21.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\22.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\23.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\24.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\25.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\26.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\27.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\28.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\29.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\3.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\4.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\5.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\6.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\7.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\8.npy...
# Checking augmentation_keypoints\bread\11\GaussianBlur\9.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\0.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\1.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\10.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\11.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\12.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\13.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\14.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\15.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\16.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\17.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\18.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\19.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\2.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\20.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\21.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\22.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\23.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\24.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\25.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\26.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\27.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\28.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\29.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\3.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\4.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\5.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\6.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\7.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\8.npy...
# Checking augmentation_keypoints\bread\11\HorizontalFlip\9.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\0.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\1.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\10.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\11.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\12.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\13.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\14.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\15.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\16.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\17.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\18.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\19.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\2.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\20.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\21.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\22.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\23.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\24.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\25.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\26.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\27.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\28.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\29.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\3.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\4.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\5.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\6.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\7.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\8.npy...
# Checking augmentation_keypoints\bread\11\RandomResize\9.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\0.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\1.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\10.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\11.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\12.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\13.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\14.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\15.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\16.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\17.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\18.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\19.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\2.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\20.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\21.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\22.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\23.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\24.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\25.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\26.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\27.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\28.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\29.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\3.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\4.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\5.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\6.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\7.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\8.npy...
# Checking augmentation_keypoints\bread\11\RandomRotate\9.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\0.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\1.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\10.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\11.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\12.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\13.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\14.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\15.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\16.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\17.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\18.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\19.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\2.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\20.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\21.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\22.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\23.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\24.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\25.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\26.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\27.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\28.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\29.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\3.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\4.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\5.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\6.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\7.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\8.npy...
# Checking augmentation_keypoints\bread\11\RandomTranslate\9.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\0.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\1.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\10.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\11.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\12.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\13.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\14.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\15.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\16.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\17.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\18.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\19.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\2.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\20.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\21.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\22.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\23.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\24.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\25.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\26.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\27.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\28.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\29.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\3.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\4.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\5.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\6.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\7.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\8.npy...
# Checking augmentation_keypoints\bread\12\GaussianBlur\9.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\0.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\1.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\10.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\11.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\12.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\13.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\14.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\15.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\16.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\17.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\18.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\19.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\2.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\20.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\21.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\22.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\23.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\24.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\25.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\26.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\27.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\28.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\29.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\3.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\4.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\5.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\6.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\7.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\8.npy...
# Checking augmentation_keypoints\bread\12\HorizontalFlip\9.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\0.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\1.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\10.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\11.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\12.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\13.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\14.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\15.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\16.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\17.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\18.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\19.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\2.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\20.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\21.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\22.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\23.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\24.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\25.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\26.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\27.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\28.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\29.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\3.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\4.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\5.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\6.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\7.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\8.npy...
# Checking augmentation_keypoints\bread\12\RandomResize\9.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\0.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\1.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\10.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\11.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\12.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\13.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\14.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\15.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\16.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\17.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\18.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\19.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\2.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\20.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\21.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\22.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\23.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\24.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\25.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\26.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\27.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\28.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\29.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\3.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\4.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\5.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\6.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\7.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\8.npy...
# Checking augmentation_keypoints\bread\12\RandomRotate\9.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\0.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\1.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\10.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\11.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\12.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\13.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\14.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\15.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\16.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\17.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\18.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\19.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\2.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\20.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\21.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\22.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\23.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\24.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\25.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\26.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\27.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\28.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\29.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\3.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\4.npy...
# Checking augmentation_keypoints\bread\12\RandomTranslate\5.npy...
# ...
# Checking augmentation_keypoints\bread\8\HorizontalFlip\27.npy...
# Checking augmentation_keypoints\bread\8\HorizontalFlip\28.npy...
# Checking augmentation_keypoints\bread\8\HorizontalFlip\29.npy...
# Checking augmentation_keypoints\bread\8\HorizontalFlip\3.npy...
# Checking augmentation_keypoints\bread\8\HorizontalFlip\4.npy...
# Checking augmentation_keypoints\bread\8\HorizontalFlip\5.npy...
# Checking augmentation_keypoints\bread\8\HorizontalFlip\6.npy...
# Checking augmentation_keypoints\bread\8\HorizontalFlip\7.npy...
# Checking augmentation_keypoints\bread\8\HorizontalFlip\8.npy...
# Checking augmentation_keypoints\bread\8\HorizontalFlip\9.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\0.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\1.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\10.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\11.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\12.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\13.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\14.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\15.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\16.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\17.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\18.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\19.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\2.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\20.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\21.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\22.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\23.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\24.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\25.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\26.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\27.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\28.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\29.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\3.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\4.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\5.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\6.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\7.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\8.npy...
# Checking augmentation_keypoints\bread\8\RandomResize\9.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\0.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\1.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\10.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\11.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\12.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\13.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\14.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\15.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\16.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\17.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\18.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\19.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\2.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\20.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\21.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\22.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\23.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\24.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\25.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\26.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\27.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\28.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\29.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\3.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\4.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\5.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\6.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\7.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\8.npy...
# Checking augmentation_keypoints\bread\8\RandomRotate\9.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\0.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\1.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\10.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\11.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\12.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\13.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\14.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\15.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\16.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\17.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\18.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\19.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\2.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\20.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\21.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\22.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\23.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\24.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\25.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\26.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\27.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\28.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\29.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\3.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\4.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\5.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\6.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\7.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\8.npy...
# Checking augmentation_keypoints\bread\8\RandomTranslate\9.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\0.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\1.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\10.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\11.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\12.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\13.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\14.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\15.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\16.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\17.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\18.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\19.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\2.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\20.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\21.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\22.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\23.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\24.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\25.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\26.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\27.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\28.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\29.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\3.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\4.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\5.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\6.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\7.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\8.npy...
# Checking augmentation_keypoints\bread\9\GaussianBlur\9.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\0.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\1.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\10.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\11.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\12.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\13.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\14.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\15.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\16.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\17.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\18.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\19.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\2.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\20.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\21.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\22.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\23.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\24.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\25.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\26.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\27.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\28.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\29.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\3.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\4.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\5.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\6.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\7.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\8.npy...
# Checking augmentation_keypoints\bread\9\HorizontalFlip\9.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\0.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\1.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\10.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\11.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\12.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\13.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\14.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\15.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\16.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\17.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\18.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\19.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\2.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\20.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\21.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\22.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\23.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\24.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\25.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\26.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\27.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\28.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\29.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\3.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\4.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\5.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\6.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\7.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\8.npy...
# Checking augmentation_keypoints\bread\9\RandomResize\9.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\0.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\1.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\10.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\11.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\12.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\13.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\14.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\15.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\16.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\17.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\18.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\19.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\2.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\20.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\21.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\22.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\23.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\24.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\25.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\26.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\27.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\28.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\29.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\3.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\4.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\5.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\6.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\7.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\8.npy...
# Checking augmentation_keypoints\bread\9\RandomRotate\9.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\0.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\1.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\10.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\11.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\12.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\13.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\14.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\15.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\16.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\17.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\18.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\19.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\2.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\20.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\21.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\22.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\23.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\24.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\25.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\26.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\27.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\28.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\29.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\3.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\4.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\5.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\6.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\7.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\8.npy...
# Checking augmentation_keypoints\bread\9\RandomTranslate\9.npy...
# All .npy files contain valid keypoints.
